# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/AI_course/Self_Coding/Month_1/WeekDay/Week2
# Out:
# /content/drive/MyDrive/AI_course/Self_Coding/Month_1/WeekDay/Week2

# %%
# !python new_file.py
# Out:
# hello world

# %%
import os
os.chdir('/content/drive/MyDrive/AI_course/Self_Coding/Month_1/WeekDay/Week2')

# %%
print(os.listdir())
# Out:
# ['new_file.py', 'new_file2.ipynb']

# %%
# !python vscode2colab_test.py
# Out:
# ...
# 100% 9912422/9912422 [00:00<00:00, 96288439.43it/s]
# Extracting ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 154509813.55it/s]
# Extracting ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 30471851.41it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 33073834.67it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# 0/5 , 0 step | Loss : 2.2915
# 0/5 , 100 step | Loss : 0.3915
# 0/5 , 200 step | Loss : 0.3534
# 0/5 , 300 step | Loss : 0.2202
# 0/5 , 400 step | Loss : 0.3571
# 0/5 , 500 step | Loss : 0.2129
# 1/5 , 0 step | Loss : 0.3853
# 1/5 , 100 step | Loss : 0.3351
# 1/5 , 200 step | Loss : 0.3623
# 1/5 , 300 step | Loss : 0.2351
# 1/5 , 400 step | Loss : 0.1695
# 1/5 , 500 step | Loss : 0.2762
# ...
